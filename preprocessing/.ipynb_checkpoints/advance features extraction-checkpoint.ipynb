# %%
# !pip install Distance
# Out:
# Collecting Distance
#   Downloading Distance-0.1.3.tar.gz (180 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: Distance
#   Building wheel for Distance (pyproject.toml): started
#   Building wheel for Distance (pyproject.toml): finished with status 'done'
#   Created wheel for Distance: filename=distance-0.1.3-py3-none-any.whl size=16346 sha256=b1e49f73cade84e4e465f4ae63cbd8f9ad13edecf1c96c58c9bc1cdbb6e226fc
#   Stored in directory: c:\users\sahil\appdata\local\pip\cache\wheels\fb\cd\9c\3ab5d666e3bcacc58900b10959edd3816cc9557c7337986322
# Successfully built Distance
# Installing collected packages: Distance
# Successfully installed Distance-0.1.3

# %%
# !pip install fuzzywuzzy
# Out:
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import re
from bs4 import BeautifulSoup
import os
import warnings
warnings.filterwarnings('ignore')

# %%
dataset = pd.read_csv('../Data/Preprocessed_data/cleaned_data_after_basic_features.csv')

# %%
dataset.isnull().sum()
# Out:
# id              0
# qid1            0
# qid2            0
# question1       0
# question2       1
# is_duplicate    0
# q1_len          0
# q2_len          0
# q1_num_words    0
# q2_num_words    0
# word_common     0
# word_total      0
# word_share      0
# dtype: int64

# %%
dataset = dataset.dropna(subset=['question2'])

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29999 entries, 0 to 29999
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            29999 non-null  int64
#  1   qid1          29999 non-null  int64
#  2   qid2          29999 non-null  int64
#  3   question1     29999 non-null  object
#  4   question2     29999 non-null  object
#  5   is_duplicate  29999 non-null  int64
#  6   q1_len        29999 non-null  int64
#  7   q2_len        29999 non-null  int64
#  8   q1_num_words  29999 non-null  int64
#  9   q2_num_words  29999 non-null  int64
#  10  word_common   29999 non-null  int64
#  11  word_total    29999 non-null  int64
#  12  word_share    29999 non-null  float64
# dtypes: float64(1), int64(10), object(2)
# memory usage: 3.2+ MB

# %%
# Advanced Features
from nltk.corpus import stopwords

def fetch_token_features(row):
    
    q1 = row['question1']
    q2 = row['question2']
    
    SAFE_DIV = 0.0001 

    STOP_WORDS = stopwords.words("english")
    
    token_features = [0.0]*8
    
    # Converting the Sentence into Tokens: 
    q1_tokens = q1.split()
    q2_tokens = q2.split()
    
    if len(q1_tokens) == 0 or len(q2_tokens) == 0:
        return token_features

    # Get the non-stopwords in Questions
    q1_words = set([word for word in q1_tokens if word not in STOP_WORDS])
    q2_words = set([word for word in q2_tokens if word not in STOP_WORDS])
    
    #Get the stopwords in Questions
    q1_stops = set([word for word in q1_tokens if word in STOP_WORDS])
    q2_stops = set([word for word in q2_tokens if word in STOP_WORDS])
    
    # Get the common non-stopwords from Question pair
    common_word_count = len(q1_words.intersection(q2_words))
    
    # Get the common stopwords from Question pair
    common_stop_count = len(q1_stops.intersection(q2_stops))
    
    # Get the common Tokens from Question pair
    common_token_count = len(set(q1_tokens).intersection(set(q2_tokens)))

    token_features[0] = common_word_count / (min(len(q1_words), len(q2_words)) + SAFE_DIV)
    token_features[1] = common_word_count / (max(len(q1_words), len(q2_words)) + SAFE_DIV)
    token_features[2] = common_stop_count / (min(len(q1_stops), len(q2_stops)) + SAFE_DIV)
    token_features[3] = common_stop_count / (max(len(q1_stops), len(q2_stops)) + SAFE_DIV)
    token_features[4] = common_token_count / (min(len(q1_tokens), len(q2_tokens)) + SAFE_DIV)
    token_features[5] = common_token_count / (max(len(q1_tokens), len(q2_tokens)) + SAFE_DIV)
    
    # Last word of both question is same or not
    token_features[6] = int(q1_tokens[-1] == q2_tokens[-1])
    
    # First word of both question is same or not
    token_features[7] = int(q1_tokens[0] == q2_tokens[0])
    
    return token_features

# %%
token_features = dataset.apply(fetch_token_features, axis=1)

dataset["cwc_min"]       = list(map(lambda x: x[0], token_features))
dataset["cwc_max"]       = list(map(lambda x: x[1], token_features))
dataset["csc_min"]       = list(map(lambda x: x[2], token_features))
dataset["csc_max"]       = list(map(lambda x: x[3], token_features))
dataset["ctc_min"]       = list(map(lambda x: x[4], token_features))
dataset["ctc_max"]       = list(map(lambda x: x[5], token_features))
dataset["last_word_eq"]  = list(map(lambda x: x[6], token_features))
dataset["first_word_eq"] = list(map(lambda x: x[7], token_features))

# %%
dataset.head()
# Out:
#        id    qid1    qid2                                          question1  \
# 0  398782  496695  532029  what is the best marketing automation tool for...
# 1  115086  187729  187730   i am poor but i want to invest  what should i do
# 2  327711  454161  454162  i am from india and live abroad  i met a guy f...
# 3  367788  498109  491396  why do so many people in the u s  hate the sou...
# 4  151235  237843   50930                 consequences of bhopal gas tragedy
#
#                                            question2  is_duplicate  q1_len  \
# 0  what is the best marketing automation tool for...             1      75
# 1  i am quite poor and i want to be very rich  wh...             0      48
# 2  t i e t to thapar university to thapar univers...             0     104
# 3  my boyfriend doesnt feel guilty when he hurts ...             0      58
# 4  what was the reason behind the bhopal gas tragedy             0      34
#
#    q2_len  q1_num_words  q2_num_words  ...  word_total  word_share   cwc_min  \
# 0      76            13            13  ...          26        0.46  0.874989
# 1      56            13            16  ...          24        0.33  0.666644
# 2     119            28            21  ...          38        0.11  0.000000
# 3     145            14            32  ...          34        0.03  0.000000
# 4      49             5             9  ...          13        0.23  0.749981
#
#     cwc_max   csc_min   csc_max   ctc_min   ctc_max  last_word_eq  \
# 0  0.874989  0.999980  0.999980  0.923070  0.923070             1
# 1  0.499988  0.714276  0.624992  0.583328  0.466664             1
# 2  0.000000  0.428565  0.272725  0.149999  0.115384             0
# 3  0.000000  0.000000  0.000000  0.000000  0.000000             0
# 4  0.599988  0.000000  0.000000  0.599988  0.333330             1
#
#    first_word_eq
# 0              1
# 1              1
# 2              0
# 3              0
# 4              0
#
# [5 rows x 21 columns]

# %%
import distance

def fetch_length_features(row):
    
    q1 = row['question1']
    q2 = row['question2']
    
    length_features = [0.0]*3
    
    # Converting the Sentence into Tokens: 
    q1_tokens = q1.split()
    q2_tokens = q2.split()
    
    if len(q1_tokens) == 0 or len(q2_tokens) == 0:
        return length_features
    
    # Absolute length features
    length_features[0] = abs(len(q1_tokens) - len(q2_tokens))
    
    #Average Token Length of both Questions
    length_features[1] = (len(q1_tokens) + len(q2_tokens))/2
    
    strs = list(distance.lcsubstrings(q1, q2))
    length_features[2] = len(strs[0]) / (min(len(q1), len(q2)) + 1)
    
    return length_features

# %%
length_features = dataset.apply(fetch_length_features, axis=1)

dataset['abs_len_diff'] = list(map(lambda x: x[0], length_features))
dataset['mean_len'] = list(map(lambda x: x[1], length_features))
dataset['longest_substr_ratio'] = list(map(lambda x: x[2], length_features))

# %%
dataset.head()
# Out:
#        id    qid1    qid2                                          question1  \
# 0  398782  496695  532029  what is the best marketing automation tool for...
# 1  115086  187729  187730   i am poor but i want to invest  what should i do
# 2  327711  454161  454162  i am from india and live abroad  i met a guy f...
# 3  367788  498109  491396  why do so many people in the u s  hate the sou...
# 4  151235  237843   50930                 consequences of bhopal gas tragedy
#
#                                            question2  is_duplicate  q1_len  \
# 0  what is the best marketing automation tool for...             1      75
# 1  i am quite poor and i want to be very rich  wh...             0      48
# 2  t i e t to thapar university to thapar univers...             0     104
# 3  my boyfriend doesnt feel guilty when he hurts ...             0      58
# 4  what was the reason behind the bhopal gas tragedy             0      34
#
#    q2_len  q1_num_words  q2_num_words  ...   cwc_max   csc_min   csc_max  \
# 0      76            13            13  ...  0.874989  0.999980  0.999980
# 1      56            13            16  ...  0.499988  0.714276  0.624992
# 2     119            28            21  ...  0.000000  0.428565  0.272725
# 3     145            14            32  ...  0.000000  0.000000  0.000000
# 4      49             5             9  ...  0.599988  0.000000  0.000000
#
#     ctc_min   ctc_max  last_word_eq  first_word_eq  abs_len_diff  mean_len  \
# 0  0.923070  0.923070             1              1             0      13.0
# 1  0.583328  0.466664             1              1             3      13.5
# 2  0.149999  0.115384             0              0             6      23.0
# 3  0.000000  0.000000             0              0            17      21.5
# 4  0.599988  0.333330             1              0             4       7.0
#
#    longest_substr_ratio
# 0              0.855263
# 1              0.224490
# 2              0.047619
# 3              0.050847
# 4              0.542857
#
# [5 rows x 24 columns]

# %%
# Fuzzy Features
from fuzzywuzzy import fuzz

def fetch_fuzzy_features(row):
    
    q1 = row['question1']
    q2 = row['question2']
    
    fuzzy_features = [0.0]*4
    
    # fuzz_ratio
    fuzzy_features[0] = fuzz.QRatio(q1, q2)

    # fuzz_partial_ratio
    fuzzy_features[1] = fuzz.partial_ratio(q1, q2)

    # token_sort_ratio
    fuzzy_features[2] = fuzz.token_sort_ratio(q1, q2)

    # token_set_ratio
    fuzzy_features[3] = fuzz.token_set_ratio(q1, q2)

    return fuzzy_features

# %%
fuzzy_features = dataset.apply(fetch_fuzzy_features, axis=1)

# Creating new feature columns for fuzzy features
dataset['fuzz_ratio'] = list(map(lambda x: x[0], fuzzy_features))
dataset['fuzz_partial_ratio'] = list(map(lambda x: x[1], fuzzy_features))
dataset['token_sort_ratio'] = list(map(lambda x: x[2], fuzzy_features))
dataset['token_set_ratio'] = list(map(lambda x: x[3], fuzzy_features))

# %%
dataset.head()
# Out:
#        id    qid1    qid2                                          question1  \
# 0  398782  496695  532029  what is the best marketing automation tool for...
# 1  115086  187729  187730   i am poor but i want to invest  what should i do
# 2  327711  454161  454162  i am from india and live abroad  i met a guy f...
# 3  367788  498109  491396  why do so many people in the u s  hate the sou...
# 4  151235  237843   50930                 consequences of bhopal gas tragedy
#
#                                            question2  is_duplicate  q1_len  \
# 0  what is the best marketing automation tool for...             1      75
# 1  i am quite poor and i want to be very rich  wh...             0      48
# 2  t i e t to thapar university to thapar univers...             0     104
# 3  my boyfriend doesnt feel guilty when he hurts ...             0      58
# 4  what was the reason behind the bhopal gas tragedy             0      34
#
#    q2_len  q1_num_words  q2_num_words  ...   ctc_max  last_word_eq  \
# 0      76            13            13  ...  0.923070             1
# 1      56            13            16  ...  0.466664             1
# 2     119            28            21  ...  0.115384             0
# 3     145            14            32  ...  0.000000             0
# 4      49             5             9  ...  0.333330             1
#
#    first_word_eq  abs_len_diff  mean_len  longest_substr_ratio  fuzz_ratio  \
# 0              1             0      13.0              0.855263          99
# 1              1             3      13.5              0.224490          69
# 2              0             6      23.0              0.047619          26
# 3              0            17      21.5              0.050847          29
# 4              0             4       7.0              0.542857          55
#
#    fuzz_partial_ratio  token_sort_ratio  token_set_ratio
# 0                  99                99               99
# 1                  67                65               74
# 2                  29                34               43
# 3                  41                23               30
# 4                  70                48               69
#
# [5 rows x 28 columns]

# %%
dataset.shape
# Out:
# (29999, 28)

# %%
sns.pairplot(dataset[['ctc_min', 'cwc_min', 'csc_min', 'is_duplicate']],hue='is_duplicate')

# %%
sns.pairplot(dataset[['ctc_max', 'cwc_max', 'csc_max', 'is_duplicate']],hue='is_duplicate')

# %%
sns.pairplot(dataset[['last_word_eq', 'first_word_eq', 'is_duplicate']],hue='is_duplicate')

# %%
sns.pairplot(dataset[['mean_len', 'abs_len_diff','longest_substr_ratio', 'is_duplicate']],hue='is_duplicate')

# %%
sns.pairplot(dataset[['fuzz_ratio', 'fuzz_partial_ratio','token_sort_ratio','token_set_ratio', 'is_duplicate']],hue='is_duplicate')

# %%
import sklearn

# %%
# Using TSNE for Dimentionality reduction for 15 Features(Generated after cleaning the data) to 3 dimention

from sklearn.preprocessing import MinMaxScaler

X = MinMaxScaler().fit_transform(dataset[['cwc_min', 'cwc_max', 'csc_min', 'csc_max' , 'ctc_min' , 'ctc_max' , 'last_word_eq', 'first_word_eq' , 'abs_len_diff' , 'mean_len' , 'token_set_ratio' , 'token_sort_ratio' ,  'fuzz_ratio' , 'fuzz_partial_ratio' , 'longest_substr_ratio']])
y = dataset['is_duplicate'].values

# %%
from sklearn.manifold import TSNE

tsne2d = TSNE(
    n_components=2,
    init='random', # pca
    random_state=101,
    method='barnes_hut',
    n_iter=1000,
    verbose=2,
    angle=0.5
).fit_transform(X)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 29999 samples in 0.071s...
# [t-SNE] Computed neighbors for 29999 samples in 4.680s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 29999
# [t-SNE] Computed conditional probabilities for sample 2000 / 29999
# [t-SNE] Computed conditional probabilities for sample 3000 / 29999
# [t-SNE] Computed conditional probabilities for sample 4000 / 29999
# [t-SNE] Computed conditional probabilities for sample 5000 / 29999
# [t-SNE] Computed conditional probabilities for sample 6000 / 29999
# [t-SNE] Computed conditional probabilities for sample 7000 / 29999
# [t-SNE] Computed conditional probabilities for sample 8000 / 29999
# [t-SNE] Computed conditional probabilities for sample 9000 / 29999
# [t-SNE] Computed conditional probabilities for sample 10000 / 29999
# [t-SNE] Computed conditional probabilities for sample 11000 / 29999
# [t-SNE] Computed conditional probabilities for sample 12000 / 29999
# [t-SNE] Computed conditional probabilities for sample 13000 / 29999
# [t-SNE] Computed conditional probabilities for sample 14000 / 29999
# [t-SNE] Computed conditional probabilities for sample 15000 / 29999
# [t-SNE] Computed conditional probabilities for sample 16000 / 29999
# [t-SNE] Computed conditional probabilities for sample 17000 / 29999
# [t-SNE] Computed conditional probabilities for sample 18000 / 29999
# [t-SNE] Computed conditional probabilities for sample 19000 / 29999
# [t-SNE] Computed conditional probabilities for sample 20000 / 29999
# [t-SNE] Computed conditional probabilities for sample 21000 / 29999
# [t-SNE] Computed conditional probabilities for sample 22000 / 29999
# [t-SNE] Computed conditional probabilities for sample 23000 / 29999
# [t-SNE] Computed conditional probabilities for sample 24000 / 29999
# [t-SNE] Computed conditional probabilities for sample 25000 / 29999
# [t-SNE] Computed conditional probabilities for sample 26000 / 29999
# [t-SNE] Computed conditional probabilities for sample 27000 / 29999
# [t-SNE] Computed conditional probabilities for sample 28000 / 29999
# [t-SNE] Computed conditional probabilities for sample 29000 / 29999
# [t-SNE] Computed conditional probabilities for sample 29999 / 29999
# [t-SNE] Mean sigma: 0.081533
# [t-SNE] Computed conditional probabilities in 0.793s
# [t-SNE] Iteration 50: error = 109.8612976, gradient norm = 0.0237117 (50 iterations in 16.318s)
# [t-SNE] Iteration 100: error = 89.2805939, gradient norm = 0.0074315 (50 iterations in 10.837s)
# [t-SNE] Iteration 150: error = 85.3497314, gradient norm = 0.0043996 (50 iterations in 10.153s)
# [t-SNE] Iteration 200: error = 83.6407623, gradient norm = 0.0032163 (50 iterations in 10.184s)
# [t-SNE] Iteration 250: error = 82.6649704, gradient norm = 0.0024411 (50 iterations in 9.399s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 82.664970
# [t-SNE] Iteration 300: error = 3.3840623, gradient norm = 0.0073316 (50 iterations in 9.626s)
# [t-SNE] Iteration 350: error = 2.7778375, gradient norm = 0.0072843 (50 iterations in 9.423s)
# [t-SNE] Iteration 400: error = 2.4477015, gradient norm = 0.0068400 (50 iterations in 9.647s)
# [t-SNE] Iteration 450: error = 2.2411151, gradient norm = 0.0064247 (50 iterations in 9.724s)
# [t-SNE] Iteration 500: error = 2.0986748, gradient norm = 0.0060886 (50 iterations in 9.768s)
# [t-SNE] Iteration 550: error = 1.9947001, gradient norm = 0.0057555 (50 iterations in 9.361s)
# [t-SNE] Iteration 600: error = 1.9164777, gradient norm = 0.0053595 (50 iterations in 9.095s)
# [t-SNE] Iteration 650: error = 1.8561335, gradient norm = 0.0049804 (50 iterations in 10.123s)
# [t-SNE] Iteration 700: error = 1.8082842, gradient norm = 0.0046007 (50 iterations in 9.771s)
# [t-SNE] Iteration 750: error = 1.7697282, gradient norm = 0.0042789 (50 iterations in 9.269s)
# [t-SNE] Iteration 800: error = 1.7377632, gradient norm = 0.0039986 (50 iterations in 9.388s)
# [t-SNE] Iteration 850: error = 1.7110373, gradient norm = 0.0037162 (50 iterations in 9.787s)
# [t-SNE] Iteration 900: error = 1.6883227, gradient norm = 0.0035039 (50 iterations in 8.825s)
# [t-SNE] Iteration 950: error = 1.6690150, gradient norm = 0.0032209 (50 iterations in 11.302s)
# [t-SNE] Iteration 1000: error = 1.6526561, gradient norm = 0.0029403 (50 iterations in 11.699s)
# [t-SNE] KL divergence after 1000 iterations: 1.652656

# %%
x_df = pd.DataFrame({'x':tsne2d[:,0], 'y':tsne2d[:,1] ,'label':y})

# draw the plot in appropriate place in the grid
sns.lmplot(data=x_df, x='x', y='y', hue='label', fit_reg=False, height=8,palette="Set1",markers=['s','o'])

# %%
tsne3d = TSNE(
    n_components=3,
    init='random', # pca
    random_state=101,
    method='barnes_hut',
    n_iter=1000,
    verbose=2,
    angle=0.5
).fit_transform(X)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 29999 samples in 0.074s...
# [t-SNE] Computed neighbors for 29999 samples in 4.946s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 29999
# [t-SNE] Computed conditional probabilities for sample 2000 / 29999
# [t-SNE] Computed conditional probabilities for sample 3000 / 29999
# [t-SNE] Computed conditional probabilities for sample 4000 / 29999
# [t-SNE] Computed conditional probabilities for sample 5000 / 29999
# [t-SNE] Computed conditional probabilities for sample 6000 / 29999
# [t-SNE] Computed conditional probabilities for sample 7000 / 29999
# [t-SNE] Computed conditional probabilities for sample 8000 / 29999
# [t-SNE] Computed conditional probabilities for sample 9000 / 29999
# [t-SNE] Computed conditional probabilities for sample 10000 / 29999
# [t-SNE] Computed conditional probabilities for sample 11000 / 29999
# [t-SNE] Computed conditional probabilities for sample 12000 / 29999
# [t-SNE] Computed conditional probabilities for sample 13000 / 29999
# [t-SNE] Computed conditional probabilities for sample 14000 / 29999
# [t-SNE] Computed conditional probabilities for sample 15000 / 29999
# [t-SNE] Computed conditional probabilities for sample 16000 / 29999
# [t-SNE] Computed conditional probabilities for sample 17000 / 29999
# [t-SNE] Computed conditional probabilities for sample 18000 / 29999
# [t-SNE] Computed conditional probabilities for sample 19000 / 29999
# [t-SNE] Computed conditional probabilities for sample 20000 / 29999
# [t-SNE] Computed conditional probabilities for sample 21000 / 29999
# [t-SNE] Computed conditional probabilities for sample 22000 / 29999
# [t-SNE] Computed conditional probabilities for sample 23000 / 29999
# [t-SNE] Computed conditional probabilities for sample 24000 / 29999
# [t-SNE] Computed conditional probabilities for sample 25000 / 29999
# [t-SNE] Computed conditional probabilities for sample 26000 / 29999
# [t-SNE] Computed conditional probabilities for sample 27000 / 29999
# [t-SNE] Computed conditional probabilities for sample 28000 / 29999
# [t-SNE] Computed conditional probabilities for sample 29000 / 29999
# [t-SNE] Computed conditional probabilities for sample 29999 / 29999
# [t-SNE] Mean sigma: 0.081533
# [t-SNE] Computed conditional probabilities in 0.959s
# [t-SNE] Iteration 50: error = 110.5643005, gradient norm = 0.0159065 (50 iterations in 39.496s)
# [t-SNE] Iteration 100: error = 86.6469727, gradient norm = 0.0043743 (50 iterations in 22.745s)
# [t-SNE] Iteration 150: error = 83.4540558, gradient norm = 0.0021840 (50 iterations in 19.108s)
# [t-SNE] Iteration 200: error = 82.2285614, gradient norm = 0.0014149 (50 iterations in 19.491s)
# [t-SNE] Iteration 250: error = 81.5535507, gradient norm = 0.0010481 (50 iterations in 19.306s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 81.553551
# [t-SNE] Iteration 300: error = 2.9835396, gradient norm = 0.0038519 (50 iterations in 25.099s)
# [t-SNE] Iteration 350: error = 2.3721917, gradient norm = 0.0030907 (50 iterations in 27.679s)
# [t-SNE] Iteration 400: error = 2.0614252, gradient norm = 0.0024669 (50 iterations in 27.521s)
# [t-SNE] Iteration 450: error = 1.8775970, gradient norm = 0.0020722 (50 iterations in 28.083s)
# [t-SNE] Iteration 500: error = 1.7558827, gradient norm = 0.0017600 (50 iterations in 27.514s)
# [t-SNE] Iteration 550: error = 1.6697514, gradient norm = 0.0015395 (50 iterations in 27.735s)
# [t-SNE] Iteration 600: error = 1.6064525, gradient norm = 0.0013416 (50 iterations in 27.806s)
# [t-SNE] Iteration 650: error = 1.5596998, gradient norm = 0.0011651 (50 iterations in 28.662s)
# [t-SNE] Iteration 700: error = 1.5253310, gradient norm = 0.0009743 (50 iterations in 30.042s)
# [t-SNE] Iteration 750: error = 1.5013026, gradient norm = 0.0007701 (50 iterations in 31.400s)
# [t-SNE] Iteration 800: error = 1.4843891, gradient norm = 0.0005919 (50 iterations in 33.060s)
# [t-SNE] Iteration 850: error = 1.4720722, gradient norm = 0.0005873 (50 iterations in 28.071s)
# [t-SNE] Iteration 900: error = 1.4627616, gradient norm = 0.0003990 (50 iterations in 30.966s)
# [t-SNE] Iteration 950: error = 1.4554126, gradient norm = 0.0003343 (50 iterations in 28.033s)
# [t-SNE] Iteration 1000: error = 1.4490200, gradient norm = 0.0002872 (50 iterations in 30.766s)
# [t-SNE] KL divergence after 1000 iterations: 1.449020

# %%
final_df = dataset.drop(columns=['id','qid1','qid2'])
print(final_df.shape)
final_df.head()
# Out:
# (29999, 25)
#                                            question1  \
# 0  what is the best marketing automation tool for...
# 1   i am poor but i want to invest  what should i do
# 2  i am from india and live abroad  i met a guy f...
# 3  why do so many people in the u s  hate the sou...
# 4                 consequences of bhopal gas tragedy
#
#                                            question2  is_duplicate  q1_len  \
# 0  what is the best marketing automation tool for...             1      75
# 1  i am quite poor and i want to be very rich  wh...             0      48
# 2  t i e t to thapar university to thapar univers...             0     104
# 3  my boyfriend doesnt feel guilty when he hurts ...             0      58
# 4  what was the reason behind the bhopal gas tragedy             0      34
#
#    q2_len  q1_num_words  q2_num_words  word_common  word_total  word_share  \
# 0      76            13            13           12          26        0.46
# 1      56            13            16            8          24        0.33
# 2     119            28            21            4          38        0.11
# 3     145            14            32            1          34        0.03
# 4      49             5             9            3          13        0.23
#
#    ...   ctc_max  last_word_eq  first_word_eq  abs_len_diff  mean_len  \
# 0  ...  0.923070             1              1             0      13.0
# 1  ...  0.466664             1              1             3      13.5
# 2  ...  0.115384             0              0             6      23.0
# 3  ...  0.000000             0              0            17      21.5
# 4  ...  0.333330             1              0             4       7.0
#
#    longest_substr_ratio  fuzz_ratio  fuzz_partial_ratio  token_sort_ratio  \
# 0              0.855263          99                  99                99
# 1              0.224490          69                  67                65
# 2              0.047619          26                  29                34
# 3              0.050847          29                  41                23
# 4              0.542857          55                  70                48
#
#    token_set_ratio
# 0               99
# 1               74
# 2               43
# 3               30
# 4               69
#
# [5 rows x 25 columns]

# %%
folder_path = '../Data/Preprocessed_data'

file_path = os.path.join(folder_path, 'final_data_for_model_training.csv')
os.makedirs(folder_path, exist_ok = True)

final_df.to_csv(file_path, index=False)
